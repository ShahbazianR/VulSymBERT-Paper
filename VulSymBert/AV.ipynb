# %%
import pandas as pd
import torch
from keybert import KeyBERT
from transformers import AutoModel, AutoTokenizer
from concurrent.futures import ThreadPoolExecutor
from tqdm import tqdm

model_path = "D:\\Italy\\sbert\\SBert models\\AV\\checkpoint_dataset5"
tokenizer = AutoTokenizer.from_pretrained(model_path)
model = AutoModel.from_pretrained(model_path, trust_remote_code=True)


device = "cuda" if torch.cuda.is_available() else "cpu"
print(device)
model.to(device)


kw_model = KeyBERT(model=model)

df = pd.read_csv("D:\\Italy\\final.csv")

def extract_keywords(text):
    if isinstance(text, str):
        
        with torch.no_grad():
            keywords = kw_model.extract_keywords(text, keyphrase_ngram_range=(1, 1), stop_words=None, top_n=5)
        return [(kw[0], 1) for kw in keywords]  
    return []


def process_data(df):
    results = []
    with ThreadPoolExecutor(max_workers=8) as executor:
        for res in tqdm(executor.map(extract_keywords, df["text"]), total=len(df)):
            results.append(res)
    return results

df["keywords"] = process_data(df)


df.to_csv("output2.csv", index=False)
# Out:
# cuda
# 100%|██████████| 137521/137521 [1:13:55<00:00, 31.00it/s]

# %%
import pandas as pd
import ast

label_to_words ={
    "N": [
    'arp',"web", 'broadcast', 'broadcasted', 'broadcasting', 'broadcastly', 'broadcasts', 'bypass', 'bypassed', 'bypassing', 'bypassly',     'bypasss', 'client', 'cliented', 'clienting', 'cliently', 'clients', 'cloudflare', 'cloudflareed', 'cloudflareing', 'cloudflarely',    'cloudflares', 'command', 'commanded', 'commanding', 'commandly', 'commands', 'connection', 'connectioned', 'connectioning',    'connectionly', 'connections', 'csrf', 'csrfed', 'csrfing', 'csrfly', 'csrfs', 'cve', 'ddos', 'ddosed', 'ddosing', 'ddosly',    'ddoss', 'dhcp', 'dhcped', 'dhcping', 'dhcply', 'dhcps', 'dns', 'dnssec', 'dnsseced', 'dnssecing', 'dnssecly', 'dnssecs', 'dos',    'enumeration', 'enumerationed', 'enumerationing', 'enumerationly', 'enumerations', 'exploitation', 'exploitationed',    'exploitationing', 'exploitationly', 'exploitations', 'exposed', 'exposeded', 'exposeding', 'exposedly', 'exposeds', 'firewall',    'firewalled', 'firewalling', 'firewallly', 'firewalls', 'gateway', 'gatewayed', 'gatewaying', 'gatewayly', 'gateways', 'handshake',    'handshakeed', 'handshakeing', 'handshakely', 'handshakes', 'http', 'httped', 'httping', 'httply', 'https', 'httpsed', 'httpsing',    'httpsly', 'httpss', 'icmp', 'icmped', 'icmping', 'icmply', 'icmps', 'injection', 'injectioned', 'injectioning', 'injectionly',    'injections', 'internet', 'interneted', 'interneting',    'internetly', 'internets', 'latency', 'latencyed', 'latencying', 'latencyly', 'latencys', 'lfi', 'malware', 'malwareed',    'malwareing', 'malwarely', 'malwares', 'manipulation', 'manipulationed', 'manipulationing', 'manipulationly', 'manipulations',    'mask', 'masked', 'masking', 'maskly', 'masks', 'mitm', 'mitmed', 'mitming', 'mitmly', 'mitmproxy', 'mitmproxyed', 'mitmproxying',    'mitmproxyly', 'mitmproxys', 'mitms', 'nat', 'network', 'networked', 'networking', 'networkly', 'networks', 'openvpn',    'openvpned', 'openvpning', 'openvpnly', 'openvpns', 'packet', 'packeted', 'packeting', 'packetly', 'packets', 'payload',    'payloaded', 'payloading', 'payloadly', 'payloads', 'phishing', 'phishinged', 'phishinging', 'phishingly', 'phishings', 'port',    'ported', 'porting', 'portly', 'ports', 'protocol', 'protocoled', 'protocoling', 'protocolly', 'protocols', 'proxy', 'proxyed',    'proxying', 'proxyly', 'proxys', 'public', 'publiced', 'publicing', 'publicly', 'publics', 'rce', 'remote', 'remoteed',    'remoteing', 'remotely', 'remotelyed', 'remotelying', 'remotelyly', 'remotelys', 'remotes', 'replay', 'replayed', 'replaying',    'replayly', 'replays', 'request', 'requested', 'requesting', 'requestly', 'requests', 'response', 'responseed', 'responseing',    'responsely', 'responses', 'rfi', 'router', 'routered', 'routering', 'routerly', 'routers', 'server', 'servered', 'servering',    'serverly', 'servers', 'session', 'sessioned', 'sessioning', 'sessionly', 'sessions', 'sniffing', 'sniffinged', 'sniffinging',    'sniffingly', 'sniffings', 'spoof', 'spoofed', 'spoofing', 'spoofinged', 'spoofinging', 'spoofingly', 'spoofings', 'spoofly',    'spoofs', 'sql', 'ssl', 'switch', 'switched', 'switching', 'switchly', 'switchs', 'tcp', 'tls', 'tor', 'traffic', 'trafficed',    'trafficing', 'trafficly', 'traffics', 'udp', 'vpn', 'xss', "remote attackers", "Microsoft Active Directory", "Silverlight", "Remote Code Execution", "authentication implementation", "Remote Desktop Protocol", "RDP", "Silverlight", "Active Directory", "XSLT", "Federation Services", "authentication attack", "daemon outage", "crafted web site", "remote code execution", "recursive compilation", "remote attackers", "Sync Framework", "SyncShareSvc", "crafted change batch data", "Windows DLL Loading", "WinForms", ".NET Framework", "information disclosure", "denial of service attack",    "remote attackers", "execute arbitrary code", "crafted web site", "memory corruption","remote code execution", "Microsoft Edge", "Internet Explorer", "XML Core Services","Exchange Server", "misparses e-mail messages", "Send As right", "denial of service vulnerability", "remote authenticated users", "remote attackers", "crafted web site", "remote execution",    "denial of service", "memory corruption", "arbitrary command execution", "XML External Entity",  "XXE vulnerability", "IBM WebSphere", "IBM InfoSphere", "IBM Cognos", "cross-site scripting", "XSS vulnerability", "inject arbitrary script", "web browser attack", "JavaScript vulnerability",  "search field exploit", "application error message", "crafted URL", "web security issue",    "exploit URL", "data disclosure", "information leakage", "XML parser", "entity reference","external entity declaration", "security misconfiguration", "remote authenticated users", "remote authentication", "authenticated user", "authenticated session",    "remote attackers", "attacker", "remote hack", "remote access", "malicious remote access",    "crafted web site", "crafted URL", "crafted request", "crafted payload",    "remote execution", "remote command execution", "execute remotely", "remote execution attack",    "denial of service", "DoS", "DDoS", "service disruption", "service outage", "system crash",    "memory corruption", "memory corruption vulnerability", "heap corruption", "stack corruption",
    "arbitrary command execution", "execute arbitrary code", "command injection", "arbitrary execution",    "XML External Entity", "XXE vulnerability", "XXE attack", "external entity injection",    "IBM WebSphere", "IBM WebSphere vulnerability", "IBM WebSphere exploit",    "IBM InfoSphere", "InfoSphere vulnerability", "IBM InfoSphere attack",    "IBM Cognos", "Cognos vulnerability", "IBM Cognos exploit",    "cross-site scripting", "XSS", "XSS attack", "script injection", "HTML injection",    "inject arbitrary script", "arbitrary script execution", "JavaScript injection", "HTML injection",    "web browser attack", "browser vulnerability", "web-based attack", "JavaScript exploit",    "JavaScript vulnerability", "JavaScript exploit", "JS attack", "browser script execution",    "search field exploit", "search field injection", "search form vulnerability", "form-based attack",    "application error message", "error message disclosure", "application log exposure",    "crafted URL", "malicious URL", "phishing URL", "exploitable URL",    "web security issue", "website security flaw", "browser security vulnerability",    "exploit URL", "exploitable web request", "crafted web exploit",    "data disclosure", "sensitive data leakage", "information leakage", "data breach",    "information leakage", "sensitive information disclosure", "confidential data exposure",    "XML parser", "XML parsing issue", "XML processing vulnerability", "parser exploit",    "entity reference", "malformed entity", "XML entity parsing", "external entity injection",    "external entity declaration", "entity injection attack", "malformed entity reference",    "security misconfiguration", "misconfigured security setting", "insecure system configuration", "remote authenticated users", "remote authentication", "authenticated user", "authenticated session",    "remote attackers", "attacker", "remote hack", "remote access", "malicious remote access",    "crafted web site", "crafted URL", "crafted request", "crafted payload",    "remote execution", "remote command execution", "execute remotely", "remote execution attack",    "denial of service", "DoS", "DDoS", "service disruption", "service outage", "system crash",    "memory corruption", "memory corruption vulnerability", "heap corruption", "stack corruption",    "arbitrary command execution", "execute arbitrary code", "command injection", "arbitrary execution",    "XML External Entity", "XXE vulnerability", "XXE attack", "external entity injection",    "IBM WebSphere", "IBM WebSphere vulnerability", "IBM WebSphere exploit",    "IBM InfoSphere", "InfoSphere vulnerability", "IBM InfoSphere attack",    "IBM Cognos", "Cognos vulnerability", "IBM Cognos exploit",    "cross-site scripting", "XSS", "XSS attack", "script injection", "HTML injection",    "inject arbitrary script", "arbitrary script execution", "JavaScript injection", "HTML injection",    "web browser attack", "browser vulnerability", "web-based attack", "JavaScript exploit",    "JavaScript vulnerability", "JavaScript exploit", "JS attack", "browser script execution",    "search field exploit", "search field injection", "search form vulnerability", "form-based attack",    "application error message", "error message disclosure", "application log exposure",    "crafted URL", "malicious URL", "phishing URL", "exploitable URL",    "web security issue", "website security flaw", "browser security vulnerability",    "exploit URL", "exploitable web request", "crafted web exploit",    "data disclosure", "sensitive data leakage", "information leakage", "data breach",    "information leakage", "sensitive information disclosure", "confidential data exposure",    "XML parser", "XML parsing issue", "XML processing vulnerability", "parser exploit",    "entity reference", "malformed entity", "XML entity parsing", "external entity injection",    "external entity declaration", "entity injection attack", "malformed entity reference",    "security misconfiguration", "misconfigured security setting", "insecure system configuration",    "directory traversal", "directory traversal attack", "traversal vulnerability",    "arbitrary file access", "arbitrary file read", "file disclosure",    "command injection", "unauthorized command execution", "command spoofing",    "session fixation", "session hijacking", "session attack",    "arbitrary code execution", "code execution exploit", "unauthorized code execution",    "REST API exploit", "API authorization bypass", "API vulnerability",    "SQL injection", "database injection", "SQLi", "database attack",    "Oracle PeopleSoft", "PeopleSoft vulnerability", "PeopleSoft attack",    "Apache vulnerability", "Apache exploit", "Tomcat vulnerability",    "PowerPath Virtual", "PowerPath exploit", "PowerPath vulnerability",    "Android security issue", "Android DoS", "Android exploit",    "Archer GRC exploit", "Archer GRC vulnerability", "RSA Archer exploit",    "email spoofing", "email exploit", "email injection",    "file upload exploit", "malicious file upload", "upload vulnerability","remote attacker", "remote attackers", "remote authenticated user", "remote authentication","denial of service", "DoS", "DDoS", "service outage", "service disruption","crafted request", "crafted input", "crafted packet", "crafted web request","network protocol", "network exploit", "network misconfiguration","information disclosure", "sensitive information disclosure", "confidential data leak","unauthorized access", "unauthorized command execution","session hijacking", "session takeover","XML external entity", "XXE", "XXE vulnerability", "XML injection",    "SQL injection", "SQLi", "database attack", "database injection","REST API exploit", "API vulnerability", "unauthorized API access","directory traversal", "path traversal", "unauthorized file access","remote command execution", "remote shell", "remote execution","authentication bypass", "bypass authentication", "privilege escalation","telnet access", "unauthorized telnet", "SSH access", "unauthorized SSH","elevation of privilege", "unauthorized privilege escalation","malformed request", "malformed input", "input validation issue","exploit URL", "malicious URL", "web-based exploit","cross-site scripting", "XSS", "JavaScript injection","arbitrary code execution", "execute arbitrary code","heap overflow", "stack overflow", "memory corruption",
    "command injection", "code injection", "code execution","buffer overflow", "heap-based buffer overflow", "stack-based buffer overflow","sandbox escape", "sandbox bypass","file inclusion", "remote file inclusion", "local file inclusion","open redirect", "unauthorized redirection","firmware vulnerability", "firmware attack", "firmware exploit","device enumeration", "device fingerprinting","network surveillance", "network monitoring attack","session fixation", "session management vulnerability","insecure web service", "insecure web API","browser exploit", "browser vulnerability", "web browser attack","HTTP header injection", "cookie manipulation","phishing", "malware injection", "malicious payload","LDAP injection", "Lightweight Directory Access Protocol exploit","FTP exploit", "unauthorized FTP access",    "IoT security issue", "IoT exploit", "IoT attack","malware persistence", "malicious persistence mechanism","crypto vulnerability", "cryptographic flaw", "weak encryption","protocol downgrade attack", "TLS downgrade", "SSL stripping","Wi-Fi attack", "wireless network attack", "Bluetooth attack","DNS poisoning", "DNS spoofing", "DNS cache poisoning","MITM attack", "man-in-the-middle attack", "interception attack","zero-day exploit", "0-day vulnerability","malicious firmware update", "insecure firmware update","device provisioning attack", "device authentication bypass","cloud security issue", "cloud service vulnerability","container security issue", "Docker vulnerability", "Kubernetes exploit","side-channel attack", "timing attack", "cache side-channel","hypervisor exploit", "virtual machine escape","hidden backdoor", "hardcoded password", "default credentials",    "router vulnerability", "switch security issue","telecom security issue", "LTE exploit", "5G security flaw","radio communication attack", "radio protocol vulnerability","metrics-collection", "syslog", "log data", "command log", "log disclosure","CSV injection", "malicious CSV", "CSV exploit","slurmd", "compute node", "arbitrary file access", "job script","telegram simulation", "online connection", "engineering-account", "RBAC system","LFI", "RFI", "Piwigo", "tab parameter","Serendipity", "dbType parameter", "bundled-libs","BorgBackup", "archive name collision", "manifest recovery","password manager", "encrypted password", "password retrieval","Automize", "hitek.jar", "encryption profile", "GPG encryption","sshProfiles.jsd", "encryptionProfiles.jsd","Tiki Wiki", "crafted pathname", "banner URL",    "use-after-free", "kvm_ioctl_create_device", "virt/kvm","DLL hijacking", "CSUNSAPI.dll", "missing DLL","D-Link DWR-932B", "TELNET", "SSH service","file traversal", "qmiweb","web HMI", "cookie validation","Qualcomm video driver", "Android kernel","Erlang", "compiled regular expressions","Qualcomm closed source","Trango Altum AC600", "hidden root account","Trango ApexLynx", "GigaLynx","Siklu EtherHaul", "device web interface","missing authorization", "fscrypt_process_policy","filesystem encryption", "ext4 encryption","LibreOffice", "out-of-bounds write","FreeType", "cff_parser_run", "vcl/source/filter/wmf","Qualcomm LTE", "pointer offset", "hypervisor vulnerability","integer overflow", "CAF Linux kernel",    "Local File Inclusion", "local file inclusion", "LFI",    "Directory Traversal", "dir traversal", "directory traversal",    "remote attacker", "remote exploit", "remote code execution (RCE)",    "remote file inclusion", "RFI",    "Bouncy Castle", "padding oracle",     "kibana", "X-Pack", "advanced settings", "short URL service",    "slurm",  "buffer over-read", "Yodl", "queue_push","prolog_error", "Prolog script",    "specially crafted URL", "crafted URL", "unauthenticated remote attacker",  "arbitrary file read", "arbitrary file overwrite", "arbitrary file creation", "arbitrary file access", "Qualcomm Snapdragon", "MSM", "CAF using the Linux kernel", "Android releases from CAF", "WLAN driver", "Volte call", "TOCTOU race condition", "TOCTOU in kernel", "Secure UI", "IMS RCS", "handover scenario", "3rd-party QTEE application", "HCI command", "kernel memory leak (remote)", "excessive memory consumption (remote)", "download a file (remote)","use-after-free vulnerability", "array index out of bounds","lack of input validation", "lack of proper bounds checking","buffer overflow", "heap overflow", "heap out of bounds","integer overflow", "off-by-one error", "overflow in video parser", "SCM command", "QTEE syscall", "RPMB listener", "RIL interface","remote input validation", "assert can be reached (remote input)","Sendio", "ATutor", "create_course.php", "get_course_icon.php",    "node-cli", "lock_file", "log_file",    "cPanel", "Roundcube update", "ModSecurity Audit logfile processing",    "backbone XSS", "Model#Escape",    "Cadence QuadSPI", "off by one",    "remote file read", "remote file write", "remote directory traversal",    "remote file disclosure", "remote memory corruption",    "remote kernel exploit", "remote heap overflow",    "remote buffer overread", "remote buffer overwrite",    "timing attack (network-based)", "spi-nor",    "log data leak", "log disclosure", "dbType POST parameter",    "bundled-libs", "arbitrary code injection", "system files read",   "Firefox OS for MSM", "QRD Android",     "vulnerability in RESTful API", "Cross Site Scripting (XSS)",    "XSS in backbone", "regex injection",     "remote file inclusion (RFI)", "upload vulnerability",    "wordpress plugin", "wp-editor plugin", "total-security plugin", "onelogin-saml-sso plugin",    "advanced-ajax-page-loader plugin", "cysteme-finder plugin", "estatik plugin",    "unauthenticated arbitrary file upload", "unrestricted file upload",    "authenticated arbitrary file upload", "CSRF arbitrary file upload",   "cpanel", "cpanellogd", "rearrangeacct", "killpvhost", "checkinfopages", "maildir_converter",   "webmail accounts", "dnsadmin-startup", "spamd-startup", "cpanellogd", "bin/fmq", "mkvhostspasswd",  "setup_global_spam_filter.pl", "chcpass", "scripts/check_system_storable",   "scripts/quotacheck", "scripts/secureit", "scripts/fixmailboxpath", "arbitrary file-overwrite",   "arbitrary file-read", "arbitrary file-write", "arbitrary file-chown", "arbitrary file-chmod",   "MySQL upgrades", "Roundcube database conversions", "process list password",   "multipart form processing error",    "Kliqqi", "arbitrary file upload", "CSRF with resultant Arbitrary File Upload",    "PHPKIT", "pkinc/admin/mediaarchive.php", "pkinc/func/default.php", "backbone xss",  "restafary", "express-restify-mongoose", "REpresentful State Transfer API", "GET /User?distinct=password", "malicious user request", "private field exposure", "cJSON", "buffer over-read", "parse_string in cJSON.c", "CSRF for deleting users", "settings-change vulnerability",  "MultiTech FaxFinder", "cleartext password", "LDAP configuration", "HTML source code in cleartext",  "Neet AirStream", "default root password", "unchangeable password", "user log files world-readable", "shared user session handling", "assert can be reached (remote)", "unauthorized memory access", "very small buffer size",  "buffer size calculation may underflow", "buffer overread occurs", "timing change injectable in RACH procedure",    "extract credential keys", "extract device administrator keys",    "IBM Financial Transaction Manager", "IBM UrbanCode Deploy", "IBM Sametime",    "IBM Tivoli Endpoint Manager", "IBM Sametime Enterprise Meeting Server",    "remote authenticated users (IBM)",     "Apache Ambari", "WebHDFS URL configuration", "file: URL",    "remote authenticated administrators",    "Cloud Foundry Garden-Linux", "Elastic Runtime", "docker image preparation",
    "delete host files", "overwrite host files",    "Apache Tomcat Realm", "timing attack (credentials)", "LockOutRealm",    "RSA Web Threat Detection", "cross site scripting (RSA)",    "Kibana custom output", "Kibana logs", "Shield authentication",    "session hijack via log files",    "encryptionProfiles.jsd", "sshProfiles.jsd", "recover encrypted passwords",    "Akamai NetSession", "DLL hijacking", "CSUNSAPI.dll",    "D-Link DWR-932B", "undocumented telnet", "undocumented SSH",    "default password (admin/root)", "qmiweb", "..%2f traversal",    "Sauter NovaWeb", "web HMI", "cookie-based auth",    "Qualcomm video driver", "Qualcomm closed source components",    "elevation of privilege vulnerability (Qualcomm)",    "improper access control (Qualcomm)", "TOCTOU race condition (Qualcomm)",   "array index out of bounds (Qualcomm)", "3rd-party QTEE application",    "excessive memory consumption (Qualcomm)", "length in HCI command validity",    "driver leak kernel memory", "integer arithmetic overflows (Qualcomm)",    "Trusted Application (TA)", "SPI interface read",    "CPVC MINK class", "QTEE syscall handler", "uninitialized link list entry",    "NULL pointer dereference (Qualcomm)", "array out-of-bounds index (Qualcomm)",    "RSA padding function (Qualcomm)", "SCM command 'TZ_INFO_GET_SECURE_STATE_LEGACY_ID'",    "supplementary services function (Qualcomm)", "RIL interface buffer size",
    "LibPNG fix multiple issues (Qualcomm)", "three image types loaded the same way",    "TZ applications not validated", "ce_pkcs1_pss_padding_verify_auto_recover_saltlen",    "RSA modulus mismatch",    "IBM X-Force ID",    "inject commands with higher privileges (IBM)",    "device administrator key", "credential key extraction",    "remote exploit (IBM)", "remote exploit (Apache)",    "remote exploit (Cloud Foundry)", "remote exploit (Tomcat)",    "modify UCD objects", "upload malicious file (Sametime)", "download malicious file",    "triggered processes (UCD)",    "security patch level", "CVE (Qualcomm)",    "malicious user to compromise", "logging debug statement",    "information disclosure (IBM)", "reading arbitrary files (Ambari)",    "detection version", "afect system by malicious users",    "MultiTech FaxFinder", "cleartext LDAP credentials",    "riot-compiler", "catastrophic backtracking",    "ProjectSend", "cFTP", "authentication bypass (ProjectSend)",    "hostapd", "low-quality PRNG", "os_random()",    "Quagga zebra daemon", "IPv6 neighbor discovery messages",    "stack-based buffer overflow (Quagga)",    "Cisco Unified Communications Manager", "Bug ID CSCuv85958",    "cleartext encryption key (Cisco)",    "Cisco NX-OS", "Bug ID CSCur22079", "blank root password",    "F5 BIG-IP", "APM access logs", "Configuration utility exploit",
    "viafintech Barzahlen", "Webhook.php", "timing discrepancy attack",    "fabarea media_upload", "TYPO3 media_upload", "pathname traversal",    "Netgear DGN2200v4", "FTP insecure root directory", "anonymous root access (Netgear)",    "Netgear password exposure",     "ZOHO Password Manager Pro", "PMP hidden service",    "futomi MP Form Mail CGI", "remote authenticated admins read files",    "Cybozu Garoon", "garoon before 4.2.2",    "Huawei switches S5700", "AAA users VTY access", "privilege escalation (Huawei)",    "TI haptic driver", "Android bug 25981545",    "Qualcomm Wi-Fi driver", "Android bug 27777501",    "IPS Community Suite", "PHP uniqid no more_entropy",    "Open-Xchange Server 6", "OX AppSuite", "script injection (Open-Xchange)",    "login screen custom messages", "defer servlet arbitrary redirect",    "IBM BigFix Remote Control", "cleartext storage (IBM)",    "IBM Cognos TM1", "obtain victim password with session key",    "Cygwin", "permission handling bug",    "Cloudera Manager 5.x", "Cloudera CDH", "privileges not revoked (Impala)",    "Oracle E-Business Suite", "AOL Diagnostic tests", "Oracle Knowledge Management",    "Huawei Wear App", "HWPSIRT-2016-03008", "SSL certificate validation",    "dotCMS", "dotTailLogServlet", "SQL injection (dotCMS)",    "Pulp", "bash $RANDOM password generation",    "Piwigo", "mt_rand output predict", "password reset token guess",    "LG Electronics bootloader", "Android bug 29189941",    "Web2py", "local file inclusion (Web2py)",    "NetCommons", "SYSTEM_ADMIN account by clerk user",    "ZOHO ManageEngine ServiceDesk Plus", "remote authenticated guest user exploit",    "Junos Space", "remote network-based users admin tasks",    "nodepdf", "child_process.exec() injection",    "Moodle 3.x", "glossary search permission",    "OSRAM Lightify Pro", "8-digit PSK",  "Sierra Wireless GX 440", "admin, rauser, sconsole passwords"


],
    "A": [
    'actionwirelessconnect', 'actionwirelessconnected', 'actionwirelessconnecting', 'actionwirelessconnectly', 'actionwirelessconnects',    'adjacent', 'adjacent-bas', 'adjacent-based', 'adjacent-baseded', 'adjacent-baseding', 'adjacent-basedly', 'adjacent-baseds',    'adjacent-basing', 'adjacent-basly', 'adjacent-bass', 'adjacent-level', 'adjacent-leveled', 'adjacent-leveling', 'adjacent-levelly',    'adjacent-levels', 'adjacent-onli', 'adjacent-onlied', 'adjacent-onliing', 'adjacent-onlily', 'adjacent-onlis', 'adjacent-only',    'adjacent-onlyed', 'adjacent-onlying', 'adjacent-onlyly', 'adjacent-onlys', 'adjacented', 'adjacenting', 'adjacently', 'adjacents',    'andlan', 'andlaned', 'andlaning', 'andlanly', 'andlans', 'approximate', 'approximateed', 'approximateing', 'approximately',    'approximates', 'assailant', 'assailanted', 'assailanting', 'assailantly', 'assailants', 'atlanssor', 'atlanssored', 'atlanssoring',    'atlanssorly', 'atlanssors', 'avalanche', 'avalancheed', 'avalancheing', 'avalanchely', 'avalanches', 'bluetooth', 'bluetoothd',    'bluetoothded', 'bluetoothding', 'bluetoothdly', 'bluetoothds', 'bluetoothed', 'bluetoothing', 'bluetoothly', 'bluetooths',
    'broadcast', 'broadcasted', 'broadcasting', 'broadcastly', 'broadcasts', 'hotspot', 'hotspoted', 'hotspoting', 'hotspotly',    'hotspots', 'internal', 'internaled', 'internaling', 'internally', 'internals', 'lan', 'lan-bas', 'lan-based', 'lan-baseded',    'lan-baseding', 'lan-basedly', 'lan-baseds', 'lan-basing', 'lan-basly', 'lan-bass', 'lan-bound', 'lan-bounded', 'lan-bounding',    'lan-boundly', 'lan-bounds', 'lan-limit', 'lan-limited', 'lan-limiteded', 'lan-limiteding', 'lan-limitedly', 'lan-limiteds',    'lan-limiting', 'lan-limitly', 'lan-limits', 'near-field', 'near-fielded', 'near-fielding', 'near-fieldly', 'near-fields',    'neighbor', 'neighbored', 'neighboring', 'neighboringed', 'neighboringing', 'neighboringly', 'neighborings', 'neighborly',    'neighbors', 'neighborsed', 'neighborsing', 'neighborsly', 'neighborss', 'network', 'network-restrict', 'network-restricted',    'network-restricteded', 'network-restricteding', 'network-restrictedly', 'network-restricteds', 'network-restricting',    'network-restrictly', 'network-restricts', 'networked', 'networking', 'networkinged', 'networkinging', 'networkingly',    'networkings', 'networkly', 'networks', 'networksed', 'networksing', 'networksly', 'networkss', 'nfc', 'nfc-base', 'nfc-based',    'nfc-baseded', 'nfc-baseding', 'nfc-basedly', 'nfc-baseds', 'nfc-baseed', 'nfc-baseing', 'nfc-basely', 'nfc-bases', 'nfc-limit',    'nfc-limited', 'nfc-limiteded', 'nfc-limiteding', 'nfc-limitedly', 'nfc-limiteds', 'nfc-limiting', 'nfc-limitly', 'nfc-limits',    'restricted', 'restricteded', 'restricteding', 'restrictedly', 'restricteds', 'router', 'routered', 'routering', 'routerly',
    'routers', 'routersed', 'routersing', 'routersly', 'routerss', 'short-range', 'short-rangeed', 'short-rangeing', 'short-rangely',    'short-ranges', 'subnet', 'subnet-limit', 'subnet-limited', 'subnet-limiteded', 'subnet-limiteding', 'subnet-limitedly',    'subnet-limiteds', 'subnet-limiting', 'subnet-limitly', 'subnet-limits', 'subneted', 'subneting', 'subnetly', 'subnets', 'vlan',    'vlan-limit', 'vlan-limited', 'vlan-limiteded', 'vlan-limiteding', 'vlan-limitedly', 'vlan-limiteds', 'vlan-limiting',    'vlan-limitly', 'vlan-limits', 'vlaned', 'vlaning', 'vlanly', 'vlans', 'vxlan', 'vxlan-bas', 'vxlan-based', 'vxlan-baseded',    'vxlan-baseding', 'vxlan-basedly', 'vxlan-baseds', 'vxlan-basing', 'vxlan-basly', 'vxlan-bass', 'vxlan-limit', 'vxlan-limited',    'vxlan-limiteded', 'vxlan-limiteding', 'vxlan-limitedly', 'vxlan-limiteds', 'vxlan-limiting', 'vxlan-limitly', 'vxlan-limits',    'vxlaned', 'vxlaning', 'vxlanly', 'vxlans', 'wi-fi', 'wi-fi-bas', 'wi-fi-based', 'wi-fi-baseded', 'wi-fi-baseding', 'wi-fi-basedly',    'wi-fi-baseds', 'wi-fi-basing', 'wi-fi-basly', 'wi-fi-bass', 'wi-fied', 'wi-fiing', 'wi-fily', 'wi-fis', 'wifi', 'wified',    'wifiing', 'wifily', 'wifis', 'wireless', 'wirelessed', 'wirelessing', 'wirelessly', 'wirelesss', "authenticated user", "authentication required", "privileged user", "user authentication",    "requires login", "login bypass", "authenticated command execution", "privilege escalation",    "admin panel access", "admin account", "authenticated SQL injection",    "session hijacking", "cookie theft", "token theft", "valid credentials",    "authentication token", "password required", "session takeover",    "access control vulnerability", "bypass authentication", "admin session hijack",
    "session replay", "authenticated API request", "access control misconfiguration",    "credential reuse", "authentication bypass", "incorrect access restriction",    "misconfigured authentication", "account hijacking", "user privilege abuse",    "privileged function access", "logged-in user attack", "authenticated API exploit",    "database authentication flaw", "authentication token leak", "authentication misconfiguration",    "multi-factor authentication bypass", "SSO vulnerability", "OAuth token leak",    "authenticated command injection", "admin-level access exploit", "privileged escalation attack",    "authenticated data modification", "privileged user attack", "root account exploit",    "session fixation", "JWT token theft", "token-based authentication flaw",    "LDAP injection", "Kerberos authentication bypass", "Windows domain authentication flaw",    "SSH key misuse", "hardcoded admin password", "backdoor account",    "SAML authentication flaw", "OAuth token hijacking", "Cloud authentication misconfiguration",    "Active Directory privilege escalation", "IAM policy misconfiguration",    "AWS credentials leak", "GCP IAM role abuse", "Azure AD privilege escalation",    "Docker registry authentication flaw", "Kubernetes authentication bypass",    "misconfigured admin permissions", "role-based access control (RBAC) misconfiguration",    "authenticated attacker", "logged-in attacker", "user-controlled access",    "privileged shell access", "root-level command execution",    "authenticated data exfiltration", "authorized user attack","authenticated user", "requires authentication", "authenticated attack",    "privileged user", "privileged account", "user with valid credentials",    "requires login", "after authentication", "needs valid credentials",    "admin access", "administrator privilege", "root access",
    "elevated privileges", "superuser access", "authenticated command execution",    "authenticated privilege escalation", "authenticated code execution",    "post-authentication exploit", "authentication bypass",    "session hijacking", "authenticated session",    "admin credentials", "user credentials", "privileged API access",    "access control bypass", "weak authentication",    "requires an account", "requires user role", "requires administrator role",    "session token theft", "authentication mechanism exploit",    "logged-in user", "authenticated file access", "authenticated file read",    "authenticated file write", "privileged action",    "privilege misconfiguration", "admin role abuse",    "trusted user exploit", "privileged function exploit",    "malicious admin action", "valid session required",    "authenticated information disclosure", "post-login exploit",    "authenticated attack vector", "authentication token hijack",    "authenticated network access", "weak session handling",    "valid user required", "authenticated API misuse",    "insecure authentication mechanism", "logged-in user vulnerability",    "authentication-required action", "authenticated misconfiguration",    "valid login session", "valid user access",    "privileged escalation via authentication", "administrator-controlled",    "post-authentication session attack", "session ID exploitation",    "authenticated administrator attack", "admin-user vulnerability",
    "authenticated software vulnerability", "admin-level attack",    "exploit requiring credentials", "post-auth exploit",    "user authentication exploit", "weak administrator authentication",    "admin privilege abuse", "exploitation by authenticated user",    "valid credentials required", "requires user token",    "authenticated network access vulnerability", "authenticated privilege abuse",    "authenticated command injection", "authenticated API command execution",    "system misconfiguration by authenticated user", "authenticated misused API",    "authenticated session manipulation", "authentication replay attack",    "authenticated access vulnerability", "authenticated role abuse",    "authenticated exploitation of misconfigured permissions",    "valid session required for exploit", "authentication token manipulation",    "privileged operation vulnerability", "authenticated API request misuse",    "authenticated privilege escalation through misconfiguration",    "authenticated vulnerability in web panel", "admin panel access exploit",    "authenticated exploit of API endpoints", "administrator function abuse",    "authenticated user ability to modify system behavior",    "authenticated execution of arbitrary commands",    "authenticated device control vulnerability",    "admin console misuse", "authenticated bypass of security controls",    "privileged function exploitation", "valid session required for attack",    "authenticated API control misuse", "weak administrator role security",    "administrator bypass vulnerability", "trusted session manipulation",    "user role exploitation", "administrator token misuse",
    "misuse of authenticated permissions", "exploit by logged-in user",    "privileged user action leading to security bypass",    "authenticated command execution exploit", "misconfigured authentication",    "post-login attack", "authenticated database access",    "authenticated software misconfiguration", "trusted authentication misuse",    "privileged account hijacking", "admin console misconfiguration",    "authenticated bypass of security features", "authenticated user exploit",    "weak authentication control abuse", "trusted user attack",    "user with valid authentication performing attack",    "user with administrator access exploiting system",    "weak authentication mechanism leading to attack",    "authentication failure leading to exploit", "insecure login mechanism",    "privileged API call exploitation", "exploitation via administrator session",    "authenticated software control abuse", "administrator-level exploit",    "exploiting trusted user session", "exploiting weak user authentication",    "trusted network access vulnerability", "authenticated device misconfiguration",    "post-authentication misused functions", "authenticated attacker bypassing controls",    "authenticated API access without proper authorization",    "weak administrator password leading to system access",    "privileged command execution by authenticated user","authenticated user", "authenticated access", "requires authentication",    "privileged user", "admin credentials", "user credentials",    "root access", "superuser access", "administrator access",    "authenticated command execution", "requires valid credentials",    "after authentication", "valid session required",    "authenticated API call", "session hijacking",    "admin panel access", "admin console exploit",
    "trusted user", "privileged session", "requires login",    "authenticated privilege escalation", "admin role abuse",    "exploited by authenticated user", "post-authentication exploit",    "authenticated bypass", "privileged function abuse",    "post-auth attack", "admin authentication exploit",    "admin-level vulnerability", "privileged API misuse",    "authenticated API exploitation", "requires administrator",    "trusted session misuse", "authenticated database access",    "authenticated information disclosure", "exploiting logged-in session",    "administrator access control flaw", "privileged user exploit",    "authenticated software misconfiguration",    "post-login vulnerability", "authenticated attack vector",    "authenticated session takeover", "valid user attack",    "authenticated code execution", "authenticated misused API",    "requires administrator privilege", "misuse of authenticated session",    "privileged function vulnerability", "exploited by logged-in user",    "requires admin role", "exploitation via administrator session",    "weak authentication control abuse", "privileged network access",    "trusted authentication bypass", "requires valid login session",    "authentication-required action", "weak admin authentication",    "authentication session manipulation", "post-authentication privilege escalation",    "admin-controlled vulnerability", "valid session misuse",    "admin session hijacking", "authenticated configuration flaw",    "privileged API call exploitation", "authenticated account abuse",    "administrator security bypass", "trusted session hijack",    "post-authenticated API request abuse", "admin user misconfiguration",    "requires user role", "valid session control exploit",
    "admin rights exploitation", "session ID exploitation",    "valid user required for exploit", "administrator privilege escalation",    "privileged access control flaw", "authenticated security misconfiguration",    "post-authentication attack method", "authenticated file access vulnerability",    "authenticated file read/write exploit", "post-authentication network vulnerability",    "admin privilege misconfiguration", "authenticated backdoor exploit",    "authenticated service abuse", "authenticated database privilege abuse",    "privileged account hijack", "administrator exploit abuse",    "admin-level security flaw", "exploiting weak user authentication",    "admin credentials exposure", "authenticated misconfiguration vulnerability",    "privileged account compromise", "trusted access misused",    "post-login access abuse", "trusted user account flaw",    "weak authentication session attack", "authenticated endpoint attack",    "trusted network privilege abuse", "authenticated API privilege misuse",    "administrator function misused", "authenticated service control bypass",    "privileged role abuse", "authenticated network misconfiguration",    "exploiting authenticated backend access", "weak admin role security",    "privileged execution abuse", "valid login session misuse",    "administrator function vulnerability", "post-authentication software weakness",    "post-authenticated request forgery", "admin user privilege abuse",    "trusted network API vulnerability", "authenticated security bypass exploit",    "weak admin login security", "trusted user privilege misconfiguration",    "authenticated admin console exploit", "administrator action vulnerability",    "session token attack", "authentication bypass vulnerability",    "exploited via privileged session", "privileged account control abuse",    "trusted authentication exploit", "authenticated request manipulation",    "administrator function misconfiguration", "authenticated privilege misused",
    "weak administrator security controls", "valid credentials misuse",    "trusted admin-level access vulnerability","authenticated user", "authenticated access", "requires authentication",    "privileged user", "admin credentials", "user credentials",    "root access", "superuser access", "administrator access",    "authenticated command execution", "requires valid credentials",    "after authentication", "valid session required",    "authenticated API call", "session hijacking",    "admin panel access", "admin console exploit",    "trusted user", "privileged session", "requires login",    "authenticated privilege escalation", "admin role abuse",    "exploited by authenticated user", "post-authentication exploit",    "authenticated bypass", "privileged function abuse",    "post-auth attack", "admin authentication exploit",    "admin-level vulnerability", "privileged API misuse",    "authenticated API exploitation", "requires administrator",    "trusted session misuse", "authenticated database access",    "authenticated information disclosure", "exploiting logged-in session",    "administrator access control flaw", "privileged user exploit",    "authenticated software misconfiguration",    "post-login vulnerability", "authenticated attack vector",    "authenticated session takeover", "valid user attack",    "authenticated code execution", "authenticated misused API",    "requires administrator privilege", "misuse of authenticated session",    "privileged function vulnerability", "exploited by logged-in user",    "requires admin role", "exploitation via administrator session",    "weak authentication control abuse", "privileged network access",    "trusted authentication bypass", "requires valid login session",    "authentication-required action", "weak admin authentication",    "authentication session manipulation", "post-authentication privilege escalation",    "admin-controlled vulnerability", "valid session misuse",    "admin session hijacking", "authenticated configuration flaw",
    "privileged API call exploitation", "authenticated account abuse",    "administrator security bypass", "trusted session hijack",    "post-authenticated API request abuse", "admin user misconfiguration",    "requires user role", "valid session control exploit",    "admin rights exploitation", "session ID exploitation",    "valid user required for exploit", "administrator privilege escalation",    "privileged access control flaw", "authenticated security misconfiguration",    "post-authentication attack method", "authenticated file access vulnerability",    "authenticated file read/write exploit", "post-authentication network vulnerability",    "admin privilege misconfiguration", "authenticated backdoor exploit",    "authenticated service abuse", "authenticated database privilege abuse",    "privileged account hijack", "administrator exploit abuse",    "admin-level security flaw", "exploiting weak user authentication",    "admin credentials exposure", "authenticated misconfiguration vulnerability",    "privileged account compromise", "trusted access misused",    "post-login access abuse", "trusted user account flaw",    "weak authentication session attack", "authenticated endpoint attack",    "trusted network privilege abuse", "authenticated API privilege misuse",    "administrator function misused", "authenticated service control bypass",    "privileged role abuse", "authenticated network misconfiguration",    "exploiting authenticated backend access", "weak admin role security",    "privileged execution abuse", "valid login session misuse",    "administrator function vulnerability", "post-authentication software weakness",    "post-authenticated request forgery", "admin user privilege abuse",    "trusted network API vulnerability", "authenticated security bypass exploit",    "weak admin login security", "trusted user privilege misconfiguration",    "authenticated admin console exploit", "administrator action vulnerability",    "session token attack", "authentication bypass vulnerability",    "exploited via privileged session", "privileged account control abuse",    "trusted authentication exploit", "authenticated request manipulation",
    "administrator function misconfiguration", "authenticated privilege misused",    "weak administrator security controls", "valid credentials misuse",    "trusted admin-level access vulnerability",    "hyper-v remote code execution", "hyper-v security feature bypass",    "hyper-v information disclosure", "hyper-v privilege escalation",    "trusted network attack", "authenticated IoT access",    "firmware update interception", "secure session hijacking",    "requires authorized network access", "adjacent network attack",    "privileged IoT control", "authenticated home automation exploit",    "trusted key reuse attack", "admin wireless vulnerability",    "authenticated input validation bypass", "authenticated remote management",    "privileged Bluetooth access", "secured IoT device compromise",    "administrator-level security flaw", "cloud authentication misconfiguration",    "IoT device privilege escalation", "trusted execution environment exploit",    "admin-level encryption failure", "requires prior authentication",    "network security misconfiguration exploit"

],
    "L": [
    'accessly', 'accesss', 'administrator', 'administratored', 'administratoring', 'administratorly', 'administrators',    'authenticationed', 'authenticationing', 'authenticationly', 'authentications', 'bypassly', 'bypasss',    'command', 'commanded', 'commanding', 'commandly', 'commands', 'credentials', 'credentialsed', 'credentialsing',    'credentialsly', 'credentialss', 'directory', 'directoryed', 'directorying', 'directoryly', 'directorys',    'dll', 'driver', 'drivered', 'drivering', 'driverly', 'drivers', 'elevateded', 'elevateding', 'elevatedly',    'elevateds', 'elevationed', 'elevationing', 'elevationly', 'elevations', 'escalationed', 'escalationing',    'escalationly', 'escalations', 'executioned', 'executioning', 'executionly', 'executions', 'exploit',    'exploited', 'exploiting', 'exploitly', 'exploits', 'file', 'fileed', 'fileing', 'filely', 'files',    'filesystem', 'filesystemed', 'filesysteming', 'filesystemly', 'filesystems', 'hijack', 'hijacked',    'hijacking', 'hijackly', 'hijacks', 'interaction', 'interactioned', 'interactioning', 'interactionly',    'interactions', 'kernel', 'kerneled', 'kerneling', 'kernelly', 'kernels', 'local', 'localed', 'localing',    'locally', 'locals', 'malware', 'malwareed', 'malwareing', 'malwarely', 'malwares', 'password', 'passworded',    'passwording', 'passwordly', 'passwords', 'permission', 'permissioned', 'permissioning', 'permissionly',    'permissions', 'privilege', 'privilegeed', 'privilegeing', 'privilegely', 'privileges', 'privilegesed',    'privilegesing', 'privilegesly', 'privilegess', 'process', 'processed', 'processing', 'processly',    'processs', 'read', 'readed', 'reading', 'readly', 'reads', 'registry', 'registryed', 'registrying',
    'registryly', 'registrys', 'root', 'rooted', 'rooting', 'rootly', 'roots', 'sandbox', 'sandboxed',    'sandboxing', 'sandboxly', 'sandboxs', 'service', 'serviceed', 'serviceing', 'servicely', 'services',    'session', 'sessioned', 'sessioning', 'sessionly', 'sessions', 'sudo', 'sudoed', 'sudoing', 'sudoly',    'sudos', 'systemed', 'systeming', 'systemly', 'systems', 'token', 'tokened', 'tokening', 'tokenly',    'tokens', 'user', 'usered', 'usering', 'userly', 'users', 'vulnerability', 'vulnerabilityed',    'vulnerabilitying', 'vulnerabilityly', 'vulnerabilitys', 'write', 'writeed', 'writeing', 'writely', 'writes',"memory corruption", "buffer overflow", "stack overflow", "heap overflow", "null pointer", "invalid pointer dereference",     "memory corruption", "stack corruption", "heap corruption", "corrupt memory",    "buffer overflow", "heap overflow", "stack overflow",   "use-after-free", "UAF", "null pointer dereference", "invalid pointer dereference",    "race condition", "TOCTOU", "timing vulnerability",    "integer overflow", "integer underflow", "signedness error",    "code execution", "arbitrary code execution", "execute arbitrary code",    "privilege escalation", "elevation of privilege", "bypass privilege",    "system service exploit", "system vulnerability", "kernel exploit",    "dll hijacking", "dynamic link library hijacking", "malicious DLL",    "file system vulnerability", "directory traversal", "file inclusion",    "sandbox escape", "sandbox bypass", "breakout from sandbox",    "unauthorized file access", "unauthorized file read", "unauthorized file write",    "malicious file execution", "crafted file exploit", "malicious document exploit",    "Windows exploit", "Windows privilege escalation",    "local exploit", "local vulnerability", "local attack",    "authentication bypass", "bypass authentication", "security feature bypass",    "Microsoft Office exploit", "Office document exploit",    "Windows kernel exploit", "kernel security flaw",    "malicious application", "malware injection", "exploit payload",    "vulnerability in Windows", "Microsoft security flaw",    "PowerShell exploit", "script execution exploit",    "Windows Defender bypass", "antivirus bypass", "security software bypass",    "SharePoint exploit", "Office automation exploit",    "Hyper-V exploit", "virtual machine escape",    "malicious PDF exploit", "crafted PDF document",    "video processing vulnerability", "media player exploit",    "RDP vulnerability", "Remote Desktop Protocol exploit",    "Windows API exploit", "system call vulnerability",    "Win32k vulnerability", "Win32 subsystem exploit",    "OLE vulnerability", "Object Linking and Embedding exploit",
    "CVE-identified vulnerability", "security patch required",    "trusted application exploit", "signed application vulnerability",    "Windows shell exploit", "shell code execution",    "malformed request exploit", "crafted input vulnerability",    "command execution", "remote command execution",    "process injection", "code injection", "malicious DLL injection",    "malicious macro", "macro execution exploit", "Office macro exploit",    "password bypass", "credential hijacking", "token hijacking",    "Windows Registry exploit", "registry manipulation",    "Active Directory exploit", "domain controller vulnerability",    "Windows SMB exploit", "file-sharing vulnerability",    "malformed image exploit", "image processing vulnerability",    "system crash exploit", "kernel panic vulnerability",    "malicious email exploit", "phishing document",    "Windows Defender bypass", "antivirus evasion",    "sandboxed application exploit", "isolation bypass",    "Excel exploit", "Word exploit", "PowerPoint exploit",    "malformed font exploit", "TrueType vulnerability",    "Windows driver exploit", "device driver vulnerability",    "signed driver vulnerability", "signed application exploit",    "Windows Boot Manager exploit", "boot process vulnerability",    "malicious update", "software patch exploit",    "Windows Installer exploit", "installation bypass",    "malicious scripting vulnerability", "script execution vulnerability",    "kernel-level privilege escalation", "privileged code execution",    "Windows network stack exploit", "network service vulnerability",    "heap spray attack", "ROP chain attack", "return-oriented programming",    "file encryption exploit", "ransomware vulnerability",    "Windows Authentication bypass", "NTLM exploit", "Kerberos vulnerability",    "Windows logging vulnerability", "event log tampering",    "hidden registry entry", "persistence exploit", "system persistence attack",
    "Microsoft Office Memory Corruption Vulnerability", "remote attackers to execute arbitrary code",    "crafted Office document",    "crafted file (Microsoft)",           "Office 2007 SP3", "Office 2010 SP2", "Office 2013 SP1", "Office 2013 RT SP1", "Office 2016",    "Excel for Mac 2011", "PowerPoint for Mac 2011", "Word for Mac 2011",     "Excel 2016 for Mac", "PowerPoint 2016 for Mac", "Word 2016 for Mac",    "Word Viewer", "Excel Viewer", "Office Compatibility Pack SP3",    "SharePoint Server 2010 SP2", "SharePoint Server 2013 SP1",    "Office Web Apps 2010 SP2", "Office Web Apps Server 2013 SP1",    "Word Automation Services", "Excel Services",    "Windows Journal Memory Corruption Vulnerability",    "DirectShow Heap Corruption Remote Code Execution",    "Kerberos in Microsoft Windows", "Windows Kerberos Security Feature Bypass",    "Windows OLE Remote Code Execution Vulnerability",    "Volume Manager Driver in Microsoft Windows",    "Video Control in Microsoft Windows",    "Windows Shell Remote Code Execution Vulnerability",    "Media Center Remote Code Execution Vulnerability",    "RemoteFX RDP USB disk access",    "Hyper-V Remote Code Execution Vulnerability",    "Hyper-V Information Disclosure Vulnerability",    "Microsoft PDF Library Buffer Overflow Vulnerability",    "crafted PDF document (Microsoft)",    "IBM Cloud Orchestrator vulnerability",    "enumerate valid users (IBM Cloud Orchestrator)",    "view tasks in the same domain",    "server slowdown via malformed URL",    "IBM Tivoli Endpoint Manager remote attacker",    "upload arbitrary files (Tivoli Endpoint Manager)",    "remote attacker could exploit", "remote attacker to upload malicious file",    "remote attacker to execute arbitrary code",    "remote attacker to cause code execution",    "remote attacker to cause memory corruption",    "remote attacker to read arbitrary files",    "crafted web site (Microsoft)", "crafted web page (Microsoft)",    "crafted .mcl file", "crafted .jnt file",    "Office document exploit",
     "Windows Remote Code Execution",    "arbitrary code execution via a crafted file" ,    "local privilege escalation", "locally exploitable", "local attack vector",    "local user", "local attacker", "local access required",    "requires local access", "local exploit", "local execution",    "local code execution", "local arbitrary code execution",    "requires physical access", "locally triggered",    "local memory corruption", "local process injection",    "local session hijacking", "exploited locally",    "privilege escalation via local access", "local root access",    "local kernel vulnerability", "local command execution",    "local privilege abuse", "local DLL injection",    "local file manipulation", "local authentication bypass",    "local information disclosure", "local security bypass",    "local shell execution", "local registry modification",    "local file permission abuse", "requires local system access",    "local user compromise", "local API misuse",    "local configuration flaw", "local filesystem attack",    "local buffer overflow", "local heap corruption",    "local DLL hijacking", "local system exploitation",    "local function abuse", "local library injection",    "local file overwrite", "local memory leak",    "local escalation of privileges", "local hardware attack",    "locally executed exploit", "local service abuse",    "local task injection", "local permission manipulation",    "local kernel access", "local hypervisor attack",    "local key injection", "local OS integrity violation",    "local IPC abuse", "local USB attack", "local network exploitation",    "local access required for attack", "local machine compromise",    "local application vulnerability", "local unauthorized access",    "local disk access flaw", "local stored credentials exposure",    "local system misconfiguration", "local debug feature abuse",    "local execution of malicious code", "local UAC bypass",    "local system tampering", "local session manipulation",    "local exploitation via application", "local service privilege abuse",
     "local vulnerability in memory", "local hardware security flaw",    "local network stack exploitation", "local DNS attack",    "local system API manipulation", "local vulnerability exposure",    "local file inclusion", "local path traversal",    "local clipboard hijacking", "local Bluetooth attack",    "local software privilege abuse", "local escalation vector",    "local script execution", "local user authentication flaw",    "local OS security weakness", "local execution via trusted process",    "local data exfiltration", "local user process compromise",    "local task scheduling abuse", "local rootkit installation",    "local session token leakage", "local registry manipulation",    "local application takeover", "local IPC privilege escalation",    "local OS command injection", "local security descriptor bypass",    "local resource abuse", "local hardware misconfiguration",    "local process monitoring bypass", "local arbitrary function execution",    "local race condition exploit", "local screen hijacking",    "local software backdoor", "local printer attack",    "local certificate mismanagement", "local mobile device exploitation",    "local application misconfiguration", "local authentication token theft",    "local critical service abuse", "local UI spoofing",    "local screen capture vulnerability", "local resource exhaustion",    "local process elevation exploit", "local audio device manipulation",    "local screen recording vulnerability", "local webcam hijacking",    "local trusted application exploit", "local cryptographic key exposure",    "local code execution via memory corruption", "local biometric bypass",    "local firmware injection", "local bootloader tampering",    "local software hook injection", "local dynamic library injection",    "local shellcode execution", "local command spoofing",    "local debug privileges abuse", "local session impersonation",    "local execution of unsigned binaries", "local system firmware vulnerability",    "local keystroke injection", "local command replay attack",    "local network credential theft", "local system privilege bypass",    "local operating system override", "local protected mode bypass",    "local clipboard attack", "local OS function abuse",
    "local browser process injection", "local network session takeover",    "local vulnerability via IPC mechanism", "local runtime execution manipulation",    "local network stack corruption", "local device driver hijacking",    "local virtual machine exploitation", "local execution of arbitrary binary",    "local filesystem privilege escalation", "local OS bypass technique",    "local kernel object hijacking", "local keychain compromise",    "local mobile OS privilege escalation", "local application context hijacking",    "local file encryption bypass", "local secure boot bypass",    "local CPU privilege abuse", "local interrupt handling attack",    "local session replay attack", "local clipboard data theft",    "local process sandbox escape", "local file integrity manipulation",    "local authentication spoofing", "local registry permission abuse",    "local system privilege manipulation", "local hypervisor misconfiguration",    "local OS function hooking", "local application binary modification",    "local system lockdown bypass", "local BIOS modification",    "local kernel security policy violation", "local hardware control attack",    "local OS privilege modification", "local system key injection",    "local trusted application privilege escalation",    "local network drive exploitation", "local filesystem injection attack",    "local software package tampering", "local WiFi stack manipulation",    "local software runtime hijack", "local cross-session impersonation",    "local system call manipulation", "local database privilege escalation",    "local application security flaw", "local device tampering",    "local secure communication hijack", "local memory space corruption",    "local credential storage exposure", "local system debug bypass",    "local low-level memory exploit", "local OS policy tampering",    "local application execution vulnerability", "local registry injection",    "local clipboard privilege abuse", "local USB function abuse",    "local UEFI security bypass", "local OS verification bypass",    "local data execution attack", "local binary integrity compromise",    "local privilege de-escalation prevention", "local software policy override",    "local API call abuse", "local OS role modification",
    "local digital signature forgery", "local application context modification",    "local network adapter manipulation", "local session tracking vulnerability",    "local integrity check bypass", "local system trust abuse",    "local file execution security flaw", "local OS data validation bypass",    "local trusted computing base attack", "local CPU mode transition attack",    "local USB device takeover", "local file signature abuse",    "local software execution security flaw", "local OS key management attack",    "local OS execution stack manipulation", "local DLL redirection",    "local GPU processing manipulation", "local system reset attack",    "local OS virtual memory bypass", "local BIOS integrity compromise",    "local filesystem ACL abuse", "local dynamic link manipulation",    "local network authentication hijack", "local OS scheduler tampering",    "local system reconfiguration exploit", "local driver execution abuse",    "local power management security flaw", "local system role modification",    "local device management security issue", "local session security override",    "local keyboard event manipulation", "local trusted network abuse",    "local system boot hijack", "local application reconfiguration vulnerability","local network policy tampering", "local OS resource leak",    "local OS privilege destruction", "local UI security bypass",    "local GPU processing attack", "local trusted computing override",    "local security subsystem manipulation", "local UI integrity compromise",    "local software version manipulation", "local Bluetooth permission abuse",    "local user", "local users", "local privilege", "local privilege escalation",    "local attack", "local exploit", "local vulnerability",    "heap-based buffer overflow", "stack-based buffer overflow", "heap corruption",    "integer overflow", "buffer overflow", "memory corruption",    "crafted file", "crafted input", "crafted document", "crafted PDF",    "remote code execution via local", "local privilege execution",    "DLL hijacking", "DLL injection", "library injection",    "race condition", "race attack", "timing attack",    "malicious local script", "malicious executable", "malicious binary",    "memory leak", "memory disclosure", "memory corruption vulnerability",    "file execution", "file exploit", "file parsing vulnerability",    "local filesystem exploit", "unauthorized local access",    "session hijacking", "session takeover",    "local process exploit", "local service escalation",    "device driver vulnerability", "driver exploit",    "kernel vulnerability", "kernel exploit", "kernel memory corruption",    "Linux kernel exploit", "Windows kernel exploit",    "unattended workstation", "session expiration issue",    "insecure local storage", "sensitive data exposure",    "unintended local information disclosure",    "local API misuse", "local API vulnerability",    "registry exploit", "local registry vulnerability",    "software misconfiguration", "configuration vulnerability",    "authentication misconfiguration", "password mismanagement",    "unauthorized admin access", "admin privilege vulnerability",    "malformed application", "malformed executable",    "code execution through crafted", "insecure session management",    "sandbox bypass", "restricted environment bypass",    "execution bypass", "unprotected process memory",
    "malicious system call", "system API exploitation",    "OS command injection", "system privilege misuse",    "terminal escape sequence exploit", "console attack",    "insecure debugging mechanism", "debugging vulnerability",    "insecure logging", "log file vulnerability",    "credential exposure", "password disclosure",    "plaintext credential storage", "unencrypted passwords",    "privileged API access", "unauthorized process execution",    "unauthorized kernel interaction", "OS interaction exploit",    "command execution via crafted input",    "malformed object handling", "insecure object processing",    "broken access control", "access control misconfiguration",    "unauthorized software interaction", "software manipulation exploit",    "malicious local component", "malicious installed application",    "insecure system service", "service takeover exploit",    "registry corruption", "DLL path hijacking",    "file inclusion exploit", "local file inclusion vulnerability",    "sandbox restriction bypass", "hypervisor exploit",    "virtualized environment exploit", "virtual machine vulnerability",    "cross-process attack", "cross-user attack",    "data persistence exploit", "malicious process persistence","execution with elevated privileges", "privileged user manipulation",    "internal application vulnerability", "internal software misconfiguration",    "heap-based buffer overflow", "stack-based buffer overflow",    "integer overflow", "memory corruption", "race condition",    "race attack", "timing attack", "malicious local script",    "malicious executable", "malicious binary", "DLL hijacking",    "DLL injection", "library injection", "unauthorized local access",    "local privilege escalation", "local privilege execution",    "privileged API access", "unauthorized process execution",    "unauthorized kernel interaction", "OS interaction exploit",    "local registry vulnerability", "system privilege misuse",    "sandbox bypass", "restricted environment bypass",    "execution bypass", "sandbox restriction bypass",    "insecure debugging mechanism", "debugging vulnerability",    "insecure logging", "log file vulnerability",    "session hijacking", "session takeover",    "malformed application", "malformed executable",    "code execution through crafted", "insecure session management",
    "terminal escape sequence exploit", "console attack",    "unprotected process memory", "malicious system call",    "command execution via crafted input", "malformed object handling",    "unauthorized software interaction", "software manipulation exploit",    "malicious local component", "malicious installed application",    "unintended local information disclosure",    "local filesystem exploit", "unauthorized admin access",    "admin privilege vulnerability", "unprotected memory region",    "device driver vulnerability", "driver exploit",    "kernel vulnerability", "kernel exploit", "kernel memory corruption",    "local process exploit", "local service escalation",    "unauthorized local access", "file execution", "file exploit",    "file parsing vulnerability", "local API misuse", "local API vulnerability",    "registry corruption", "DLL path hijacking", "heap corruption",    "file inclusion exploit", "local file inclusion vulnerability",    "hypervisor exploit", "virtualized environment exploit",    "virtual machine vulnerability", "cross-process attack",    "cross-user attack", "data persistence exploit",    "malicious process persistence", "privileged user manipulation",    "internal application vulnerability", "internal software misconfiguration",
    "local privilege escalation", "privilege escalation",    "unauthorized local access", "local memory corruption", "heap corruption",    "heap-based buffer overflow", "stack-based buffer overflow", "integer overflow",    "race condition", "timing attack", "malicious local script", "malicious binary",    "DLL hijacking", "DLL injection", "sandbox bypass",    "sandbox restriction bypass", "OS interaction exploit", "local filesystem exploit",    "debugging vulnerability", "local process exploit",    "device driver vulnerability", "driver exploit", "local file inclusion",    "unprotected memory region", "kernel memory corruption", "hypervisor exploit",    "virtualized environment exploit", "virtual machine vulnerability",    "unauthorized admin access", "admin privilege vulnerability",    "cross-process attack", "cross-user attack", "privileged API access",    "unauthorized software interaction", "command execution via crafted input",    "unprotected registry access",    "malformed executable", "malformed application", "session hijacking",    "unauthorized kernel interaction", "memory corruption exploit",    "unauthorized process execution", "malicious local component",    "local security bypass", "memory corruption via crafted input",    "privilege escalation vulnerability", "local root access",    "exploitable local vulnerability", "malicious firmware update",    "device compromise", "malicious USB device", "unauthorized firmware execution",    "unauthorized application execution", "kernel mode execution",    "direct hardware access", "file permission exploit",    "unauthorized system call", "system misconfiguration exploit",    "malicious background process", "privileged daemon attack",    "unauthorized firmware modification", "bypass secure boot",    "untrusted local execution", "firmware backdoor",    "internal OS attack", "kernel API misuse",    "local environment manipulation", "secure storage bypass",    "sandbox policy violation", "custom bootloader exploit",    "malicious registry modification", "rootkit-like behavior",    "untrusted binary execution", "boot process hijacking",    "unauthorized OS patching", "kernel module injection",
    "memory management exploit", "ring 0 execution",    "bootloader privilege escalation", "custom kernel exploit",    "unauthorized CPU instruction execution",    "executable integrity bypass", "malicious EFI modification",    "bypass trusted computing", "runtime privilege modification",    "unauthorized rootkit installation", "system integrity compromise",    "insecure system API", "protected memory exploit",    "internal application exploit", "restricted area access",    "bypass user authentication", "internal storage manipulation",    "privileged key access", "system partition exploit",    "malicious OS component", "privileged access hijacking",    "local device takeover", "OS control bypass",    "insecure OS upgrade", "unauthorized OS image loading",    "system-level compromise", "malicious recovery mode",    "trusted computing bypass", "unauthorized secure mode access"


],
    "P": [
    'boot', 'booted', 'booting', 'break', 'breaked', 'breaking', 'busbar', 'card', 'carded', 'carding',     'chip', 'chiped', 'chiping', 'chipset', 'circuit', 'circuited', 'circuiting', 'connector', 'connectored',    'connectoring', 'debug', 'debuged', 'debugging', 'desoldering', 'device', 'deviceed', 'deviceing',    'disassemble', 'disassembleed', 'disassembleing', 'firmware', 'firmwareed', 'firmwareing', 'force',    'forceed', 'forceing', 'hardware', 'hardware-based', 'hardware-level', 'impinging', 'interference',    'interlocking', 'intrusion', 'lock', 'locked', 'locking', 'malfunctioning', 'manipulate', 'manipulated',
    'manipulating', 'memory', 'memoryed', 'microchip', 'microchiped', 'microchiping', 'modification',    'modifications', 'passwordpin', 'passwordpined', 'passwordpining', 'physical', 'physical-based',    'physically', 'pin', 'pinafore', 'pinafored', 'pinaforeing', 'pinch', 'pinched', 'pinching', 'pink',    'pinked', 'pinking', 'pinny', 'pinnyed', 'pinnying', 'pins', 'placard', 'placarded', 'placarding',    'power', 'powered', 'powering', 'pressure', 'pressured', 'pressuring', 'probe', 'probed', 'probing',    'reauthentication', 'reboot', 'rebooted', 'rebooting', 'replacement', 'rowlock', 'rowlocked',    'rowlocking', 'scorecard', 'scorecarded', 'scorecarding', 'short-circuit', 'short-circuited',    'short-circuiting', 'signal', 'signaled', 'signaling', 'signalize', 'signalized', 'signalizing',    'signally', 'soldering', 'tamper', 'tampered', 'tampering', 'tapping', 'tapped', 'tappinging',    'tholepin', 'tholepined', 'tholepining', 'touch', 'touchable', 'touching', 'unlocked', 'unlockeded',
    'unlockeding', 'usb', 'willpower', 'willpowered', 'willpowering', "physically proximate", "factory reset", "factory reset protection", "bypass protection", "delete data", "device provisioning", "setup wizard","physically proximate", "factory reset", "factory reset protection", "bypass protection", "delete data", "device provisioning", "setup wizard","usb device", "crafted usb", "physical access", "hardware attack", "firmware exploit", "hid device", "media device", "driver exploit", "device enumeration", "usb interface",    "motherboard", "console port", "engineering console", "line card", "physical console", "console access", "firmware", "firmware modification", "BIOS attack", "ROM attack", "unsigned firmware",  "chip", "chipset", "EEPROM", "flash memory", "hardware vulnerability",
    "tamper", "tampering", "tamper detection", "tamper protection",   "physical authentication bypass", "physical token", "physical memory", "memory extraction", "unencrypted storage",  "DMA attack", "Thunderbolt attack",
    "device firmware", "bootloader modification",  "removable media", "USB attack", "malicious USB",  "debug access", "engineering mode", "console access", "serial console", "debugging interface",  "factory reset protection bypass", "FRP bypass",
    "hardcoded encryption key", "unencrypted data",  "Cisco ASR", "Cisco cBR", "Cisco IOS XE", "Boston Scientific", "ZOOM LATITUDE PRM", "APFS", "FileVault", "Thunderbolt", "Johnson & Johnson Ethicon", "Alaris 8015 PC unit", "Huawei P9", "Samsung Galaxy",
    "Apple macOS", "macOS vulnerability", "Apple iOS",  "Windows Lock Screen Vulnerability", "physical access control bypass", "local privilege escalation",  "device tampering", "unauthorized physical access",  "malicious bootloader", "hypervisor attack", "unsigned hypervisor",   "external console access", "local attack vector",
    "hardware exploit", "firmware compromise", "physical proximity attack", "direct device manipulation",  "memory extraction", "secure boot bypass"
]
}


def safe_eval(value):
    try:
        if isinstance(value, str):
            return ast.literal_eval(value)
        elif isinstance(value, list):
            return value
        else:
            print(f"Value is not a valid format: {value}")
            return []
    except Exception as e:
        print(f"Error evaluating value: {value}, Error: {e}")
        return []

def update_keywords(row):
    label = row['av']
    target_words = label_to_words.get(label, [])

    keywords_list = safe_eval(row['keywords'])  

    updated_keywords = []
    for word, weight in keywords_list:
        if word in target_words:
            updated_keywords.append((word, 10))
        else:
            updated_keywords.append((word, weight))

    return updated_keywords


df['keywords'] = df['keywords'].fillna("[]")


df['updated_keywords'] = df.apply(update_keywords, axis=1)


print(df.head())
# Out:
#               ID                                               text  \
# 0  CVE-2016-0002  The Microsoft (1) VBScript 5.7 and 5.8 and (2)...
# 1  CVE-2016-0003  Microsoft Edge allows remote attackers to exec...
# 2  CVE-2016-0005  Microsoft Internet Explorer 9 through 11 allow...
# 3  CVE-2016-0006  The sandbox implementation in Microsoft Window...
# 4  CVE-2016-0007  The sandbox implementation in Microsoft Window...
#
#                                    vectorString av ac pr ui  s  c  i  a  \
# 0  CVSS:3.0/AV:N/AC:H/PR:N/UI:R/S:U/C:H/I:H/A:H  N  H  N  R  U  H  H  H
# 1  CVSS:3.0/AV:N/AC:L/PR:N/UI:R/S:C/C:H/I:H/A:H  N  L  N  R  C  H  H  H
# 2  CVSS:3.0/AV:N/AC:L/PR:N/UI:R/S:U/C:N/I:L/A:N  N  L  N  R  U  N  L  N
# 3  CVSS:3.0/AV:L/AC:L/PR:L/UI:R/S:U/C:H/I:H/A:H  L  L  L  R  U  H  H  H
# 4  CVSS:3.0/AV:L/AC:L/PR:N/UI:R/S:U/C:H/I:H/A:H  L  L  N  R  U  H  H  H
#
#    score baseSeverity                                           keywords  \
# ...

# %%
import os
import pandas as pd
import ast
import torch
import torch.nn as nn
from torch.utils.data import Dataset
from transformers import AutoTokenizer, AutoModel, TrainingArguments, Trainer
import numpy as np
from sklearn.metrics import accuracy_score, balanced_accuracy_score, f1_score, precision_score, recall_score
from sklearn.model_selection import train_test_split


os.environ["WANDB_DISABLED"] = "true"


# df = pd.read_csv("/content/drive/MyDrive/AV/symbolicAI/your_file.csv")


unique_labels = sorted(df['pr'].unique())
label2id = {label: i for i, label in enumerate(unique_labels)}
id2label = {i: label for label, i in label2id.items()}
df['label_id'] = df['pr'].map(label2id)


train_df, val_df = train_test_split(df, test_size=0.2, stratify=df['pr'], random_state=42)



def build_inputs_and_weights(keywords, tokenizer, max_length=64):
   
    tokens = []
    weights = []
    for word, weight in keywords:
        
        word_tokens = tokenizer.tokenize(word)
        tokens.extend(word_tokens)
        weights.extend([weight] * len(word_tokens))

    
    cls_token = tokenizer.cls_token if tokenizer.cls_token is not None else "[CLS]"
    sep_token = tokenizer.sep_token if tokenizer.sep_token is not None else "[SEP]"
    tokens = [cls_token] + tokens + [sep_token]
    weights = [1] + weights + [1]

    input_ids = tokenizer.convert_tokens_to_ids(tokens)
    attention_mask = [1] * len(input_ids)

   
    if len(input_ids) < max_length:
        pad_length = max_length - len(input_ids)
        input_ids = input_ids + [tokenizer.pad_token_id] * pad_length
        attention_mask = attention_mask + [0] * pad_length
        weights = weights + [1] * pad_length
    else:
        input_ids = input_ids[:max_length]
        attention_mask = attention_mask[:max_length]
        weights = weights[:max_length]

    return {
        "input_ids": torch.tensor(input_ids, dtype=torch.long),
        "attention_mask": torch.tensor(attention_mask, dtype=torch.long),
        "token_weights": torch.tensor(weights, dtype=torch.float)
    }



class HybridDataset(Dataset):
    def __init__(self, df, tokenizer, max_length_text=256, max_length_sym=64):
        
        self.df = df.reset_index(drop=True)
        self.tokenizer = tokenizer
        self.max_length_text = max_length_text
        self.max_length_sym = max_length_sym

    def __len__(self):
        return len(self.df)

    def __getitem__(self, idx):
        row = self.df.iloc[idx]
        
        text = row['text']
        encoding_text = self.tokenizer(text, padding='max_length', truncation=True,
                                       max_length=self.max_length_text, return_tensors='pt')
        encoding_text = {k: v.squeeze(0) for k, v in encoding_text.items()}

        
        updated_keywords = row['updated_keywords']
        if isinstance(updated_keywords, str):
            updated_keywords = ast.literal_eval(updated_keywords)
        encoding_sym = build_inputs_and_weights(updated_keywords, self.tokenizer, max_length=self.max_length_sym)

        label = torch.tensor(row['label_id'], dtype=torch.long)

        return {
            "input_ids_text": encoding_text['input_ids'],
            "attention_mask_text": encoding_text['attention_mask'],
            "input_ids_sym": encoding_sym['input_ids'],
            "attention_mask_sym": encoding_sym['attention_mask'],
            "token_weights_sym": encoding_sym['token_weights'],
            "labels": label
        }



class HybridModel(nn.Module):
    def __init__(self, base_model, num_labels):
        
        super().__init__()
        self.base_model = base_model  
        hidden_size = base_model.config.hidden_size

        
        self.gate_layer = nn.Linear(hidden_size * 2, hidden_size)
        self.sigmoid = nn.Sigmoid()

        
        self.classifier = nn.Linear(hidden_size, num_labels)

    def forward(self,
                input_ids_text=None,
                attention_mask_text=None,
                input_ids_sym=None,
                attention_mask_sym=None,
                token_weights_sym=None,
                labels=None):
        
        outputs_text = self.base_model(input_ids=input_ids_text,
                                       attention_mask=attention_mask_text,
                                       output_hidden_states=True,
                                       return_dict=True)
        
        text_repr = outputs_text.hidden_states[-1][:, 0, :]  # (batch, hidden_size)

       
        embedding = self.base_model.get_input_embeddings()
        embeddings_sym = embedding(input_ids_sym)  # (batch, seq_len_sym, hidden_size)
        
        weighted_embeddings_sym = embeddings_sym * token_weights_sym.unsqueeze(-1)
        masked_embeddings = weighted_embeddings_sym * attention_mask_sym.unsqueeze(-1)
        sum_embeddings_sym = masked_embeddings.sum(dim=1) 
        valid_tokens = attention_mask_sym.sum(dim=1, keepdim=True) + 1e-8
        symbolic_repr = sum_embeddings_sym / valid_tokens  

        
        combined_input = torch.cat([text_repr, symbolic_repr], dim=1)  # (batch, 2*hidden_size)
        gate = self.sigmoid(self.gate_layer(combined_input))  # (batch, hidden_size)
        combined_repr = gate * symbolic_repr + (1 - gate) * text_repr

       
        logits = self.classifier(combined_repr)

        loss = None
        if labels is not None:
            loss_fct = nn.CrossEntropyLoss()
            loss = loss_fct(logits, labels)

        return {"loss": loss, "logits": logits}




model_path = "D:\\Italy\\sbert\\SBert models\\PR\\checkpoint_dataset5"


tokenizer = AutoTokenizer.from_pretrained(model_path)


base_model = AutoModel.from_pretrained(model_path, trust_remote_code=True)


num_labels = len(unique_labels)


hybrid_model = HybridModel(base_model, num_labels)


device = "cuda" if torch.cuda.is_available() else "cpu"
hybrid_model.to(device)


train_dataset = HybridDataset(train_df, tokenizer, max_length_text=256, max_length_sym=64)
val_dataset   = HybridDataset(val_df, tokenizer, max_length_text=256, max_length_sym=64)



def compute_metrics(eval_pred):
    logits, labels = eval_pred
    preds = np.argmax(logits, axis=1)
    acc = accuracy_score(labels, preds)
    bal_acc = balanced_accuracy_score(labels, preds)
    f1 = f1_score(labels, preds, average='weighted')
    prec = precision_score(labels, preds, average='weighted')
    rec = recall_score(labels, preds, average='weighted')
    return {
        "accuracy (validation)": acc,
        "weighted_accuracy": bal_acc,
        "f1": f1,
        "precision": prec,
        "recall": rec
    }



training_args = TrainingArguments(
    output_dir="./results",
    num_train_epochs=10,
    per_device_train_batch_size=8,
    per_device_eval_batch_size=8,
    warmup_steps=500,
    weight_decay=0.01,
    logging_dir='./logs',
    logging_steps=10,
    eval_strategy="epoch",   
    save_strategy="epoch",
    report_to=[]  
)

trainer = Trainer(
    model=hybrid_model,
    args=training_args,
    train_dataset=train_dataset,
    eval_dataset=val_dataset, 
    compute_metrics=compute_metrics
)



trainer.train()



def predict_label(description, updated_keywords_str):
    
    encoding_text = tokenizer(description, return_tensors='pt', truncation=True, padding='max_length', max_length=256)
    encoding_text = {k: v.to(device) for k, v in encoding_text.items()}

  
    updated_keywords = ast.literal_eval(updated_keywords_str) if isinstance(updated_keywords_str, str) else updated_keywords_str
    encoding_sym = build_inputs_and_weights(updated_keywords, tokenizer, max_length=64)
    encoding_sym = {k: v.unsqueeze(0).to(device) for k, v in encoding_sym.items()}

   
    outputs = hybrid_model(
        input_ids_text=encoding_text['input_ids'],
        attention_mask_text=encoding_text['attention_mask'],
        input_ids_sym=encoding_sym['input_ids'],
        attention_mask_sym=encoding_sym['attention_mask'],
        token_weights_sym=encoding_sym['token_weights']
    )
    logits = outputs["logits"]
    predicted_class_id = logits.argmax(dim=1).item()
    return id2label[predicted_class_id]
